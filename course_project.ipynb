# %% [markdown]
# # Project

# %% [markdown]
# Organisms analysed:
# * Xenopus wittei
# * Xenopus pygmaeus
# * Xenopus amieti
# * Xenopus parafraseri
# * Xenopus kobeli
# * Xenopus petersii
# * Xenopus laevis
# * Xenopus victorianus
# * Xenopus poweri
# * Xenopus gilli

# %% [markdown]
# <img src="images/project_aic_model.png">

# %% [markdown]
# ## NJ alignment with Mafft

# %% [markdown]
# <img src="images/project_nj.png">

# %%
!~/Prog/tools/raxml-ng_v0/raxml-ng --all --redo --msa data/project/xenopus_merged_aln_raxml.fa --bs-trees=500 --model=GTR+G+I

# %%
from Bio import Phylo
from matplotlib import pyplot as plt

# %%
with open('data/project/xenopus_merged_aln_raxml.fa.raxml.support', 'r') as f:
    tree = Phylo.read(f, 'newick')
tree.ladderize()

# %%
fig = plt.figure(figsize=(15, 10))
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(tree, do_show=False, axes=axes)
