# %% [markdown]
# ## HW3 Tree construction

# %%
from matplotlib import pyplot as plt
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
from Bio.Phylo.TreeConstruction import DistanceCalculator
from Bio import AlignIO, Phylo

# %% [markdown]
# ### Construct trees

# %%
with open('data/prank_sup35/SUP35_aln.best.fas') as f:
    aln = AlignIO.read(f, 'fasta')
constructor = DistanceTreeConstructor()
calculator = DistanceCalculator('identity')
dm = calculator.get_distance(aln)
upgmatree = constructor.upgma(dm)
upgmatree.ladderize()

njtree = constructor.nj(dm)
njtree.ladderize()

# %% [markdown]
# ### UPGMA

# %%
fig = plt.figure(figsize=(10, 10))
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(upgmatree, do_show=False, axes=axes)

# %% [markdown]
# ### NJ

# %%
fig = plt.figure(figsize=(10, 10))
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(njtree, do_show=False, axes=axes)

# %% [markdown]
# ## Model analysis with jModelTest2

# %% [markdown]
# Best model according to the Akaike information criterion(AIC)

# %% [markdown]
# <img src="images/aic_model.png">

# %% [markdown]
# Best model according to the Bayesian Information Criterion (BIC)

# %% [markdown]
# <img src="images/bic_model.png">
